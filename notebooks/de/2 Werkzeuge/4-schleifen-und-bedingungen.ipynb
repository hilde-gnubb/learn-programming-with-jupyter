# %% [markdown]
# # Lass den Abenteurer den Schatz automatisch finden
#
# Mit den Funktionen haben wir nun gelernt, wie wir an bestimmten Wegpunkten besondere Aktionen durchführen können. In den letzten Lektionen musstest du
# immer selbst den Weg eingeben, um zum Ziel zu gelangen. Diese Vorgehensweise wollen wir nun mit Hilfe von **Schleifen** und **Bedingungen** automatisieren, sodass du nur einmal klicken musst, um den Abenteurer automatisch bis zum **Schatz** zur bringen. Auf seiner automatischen Reise werden die benötigten Lebenspunkte automatisch aufsummiert.
#
# <center>
# <img src="../../../images/de/schatzkarte/treasure_map_locations.png" height=800>
# </center>

# %% [markdown]
# Zunächst lernen wir die Grundlagen von **Schleifen** und **Bedingungen** anhand einfacher Beispiele. Danach wenden wir diese an unserer Schatzkarte an.

# %% [markdown]
# ## 1. For-Schleifen
#
# Die For-Schleife ("Für") ist ein wichtiges Werkzeug um eine Reihe von Elementen zu durchlaufen. Sie **iteriert** jede Runde durch ein Element einer listen-artigen Struktur. Hier ein Beispiel:

# %%
meine_liste = [1, "ich", "du", 2, "irgendwas", 3, []]

for element in meine_liste:
    print(element)
# Out:
# 1
# ich
# du
# 2
# irgendwas
# 3
# []

# %% [markdown]
# ### Aufgabe 1
#
# <a id='aufgabe_1'></a>
#
# 1. Erstelle eine Liste, die deine Lieblingsschulfächer enthält.
# 2. Iteriere über die Listenelemente und printe sie aus

# %%
faecher = "Mathe" 

# Iteriere über die Liste und printe

# %% [markdown]
# ## 2. If-(Else-)Anweisungen
#
# Mit der Hilfe der If-(Else-)Anweisung ("Wenn"-"Sonst") kannst du Bedingungen erstellen, ob Code durchlaufen werden soll.

# %%
# Verändere den Wert und schaue, was passiert
mein_wert = 1

if mein_wert < 2:
    print("Mein Wert is kleiner als 2.")

if mein_wert >= 2:
    print("Mein Wert ist größer oder gleich als 2")
# Out:
# Mein Wert is kleiner als 2.

# %% [markdown]
# Zustätzlich zu if gibt es auch **else**. Damit kannst du obiges Beispiel auch so schreiben:

# %%
# Verändere den Wert und schaue, was passiert
mein_wert = 1

if mein_wert < 2:
    print("Mein Wert is kleiner als 2.")
else:
    print("Mein Wert ist größer oder gleich als 2")
# Out:
# Mein Wert is kleiner als 2.

# %% [markdown]
# Nun kann man z.B. For und If kombinieren.

# %%
meine_liste = [1, 5, 8, 3, 7]
for element in meine_liste:
    print("Wert ", element)
    if element < 2:
        print("Mein Wert is kleiner als 2.")
    else:
        print("Mein Wert ist größer oder gleich als 2")
# Out:
# Wert  1
# Mein Wert is kleiner als 2.
# Wert  5
# Mein Wert ist größer oder gleich als 2
# Wert  8
# Mein Wert ist größer oder gleich als 2
# Wert  3
# Mein Wert ist größer oder gleich als 2
# Wert  7
# Mein Wert ist größer oder gleich als 2

# %% [markdown]
# Eine Möglichkeit, bei Erreichen einer Bedingung auszusteigen, kann man mit dem Befehl **break** machen.

# %%
# Verlasse die for-Schleife beim ersten Erreichen einer Zahl, die größer als 2 ist

meine_liste = [1, 5, 8, 3, 7]
for element in meine_liste:
    print("Wert ", element)
    if element < 2:
        print("Mein Wert is kleiner als 2.")
    else:
        print("Mein Wert ist größer oder gleich als 2")
        break

print("Die erste Zahl der Liste größer oder gleich 2 ist", element)
# Out:
# Wert  1
# Mein Wert is kleiner als 2.
# Wert  5
# Mein Wert ist größer oder gleich als 2
# Die erste Zahl der Liste größer oder gleich 2 ist 5

# %% [markdown]
# ### Aufgabe 2
#
# <a id='aufgabe_2'></a>
#
# 1. Verwende die For-Schleife aus [Aufgabe 1](#aufgabe-1)
# 2. Frage deinen Banknachbarn, welches seine Lieblingsfächer sind. Das erste was er oder sie nennt, dass auch in deiner Liste auftauchst, schreibst du der Variablen **lieblingsfach_des_nachbarn** zu
# 3. Beim Iterieren soll nun 'Wir haben ein match!' geprintet werden, wenn dieses Lieblingsfach auftritt.

# %%
# Hinweis: Ein Vergleich von Zeichenketten wird mit == erfüllt (Zwei Ist-Gleichs!)
z1 = "abc"
z2 = "abc"
z3 = "bcd"

print("z1 gleich z2? ->", z1 == z2)
print("z1 gleich z3? ->", z1 == z3)
# Out:
# z1 gleich z2? -> True
# z1 gleich z3? -> False

# %%
faecher = 
lieblingsfach_des_nachbarn = 

nachricht = "Wir haben ein match!"

# Iteriere über die Liste und printe
# Out:
#   Cell In[8], line 1
#     faecher =
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. While-Schleife
#
# Die While-Schleife ("Solange") wird solange wiederholt, bis eine bestimmte Bedingung erfüllt ist.

# %%
# Diese Funktion gibt dir bei jedem Aufruf eine zufüllige Zahl zwischen 1 und 6 aus
from schleifen_bedingungen import einmal_wuerfeln
meine_zahl = einmal_wuerfeln()
meine_zahl
# Out:
# 6

# %%
meine_wunschzahl = 6
meine_zahl = 0  # Noch nicht gewürfelt

while meine_wunschzahl != meine_zahl:
    print("Meine gewürfelte Zahl ist:", meine_zahl)
    meine_zahl = einmal_wuerfeln()

print("Geschafft! Meine gewürfelte Zahl ist:", meine_zahl)
# Out:
# Meine gewürfelte Zahl ist: 0
# Meine gewürfelte Zahl ist: 5
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 5
# Meine gewürfelte Zahl ist: 2
# Geschafft! Meine gewürfelte Zahl ist: 6

# %% [markdown]
# ## Aufgabe 3
#
# 1. Kopiere den Code vom obigen While-Beispiel in die Zelle hier darunter
# 2. Verändere den Code so, dass solange gewüfelt wird, bis du zweimal hintereinander deine Wunschzahl geworfen wurde.

# %%
a=6
b=6
c=6

nicht_zweimal_hintereinander_wunschzahl = a!=c or a!=b
nicht_zweimal_hintereinander_wunschzahl
# Out:
# False

# %%
meine_wunschzahl = 6
meine_zahl_vorher = 0 # Noch nicht gewürfelt
meine_zahl = 0  # Noch nicht gewürfelt

while meine_wunschzahl != meine_zahl or meine_wunschzahl!= meine_zahl_vorher:
    meine_zahl_vorher = meine_zahl
    print("Meine gewürfelte Zahl ist:", meine_zahl)
    meine_zahl = einmal_wuerfeln()

print("Geschafft! Meine beiden Zahlen sind:", meine_zahl ,"und", meine_zahl_vorher)

# Kopiere die While-Schleife hier herunter und passe sie an
# Out:
# Meine gewürfelte Zahl ist: 0
# Meine gewürfelte Zahl ist: 1
# Meine gewürfelte Zahl ist: 1
# Meine gewürfelte Zahl ist: 6
# Meine gewürfelte Zahl ist: 2
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 1
# Meine gewürfelte Zahl ist: 2
# Meine gewürfelte Zahl ist: 1
# Meine gewürfelte Zahl ist: 4
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 4
# Meine gewürfelte Zahl ist: 6
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 2
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 2
# Meine gewürfelte Zahl ist: 6
# Meine gewürfelte Zahl ist: 3
# Meine gewürfelte Zahl ist: 6
# Geschafft! Meine beiden Zahlen sind: 6 und 6

# %% [markdown]
# ## Automatische Wegfindung
#
# Wieder wollen wir die Karte etwas weniger komplex machen, um die anstehende Aufgabe zu vereinfachen. Daher beschränken wir uns in unseren Betrachtungen auf folgende Karte:

# %%
from funktionen import *
from funktionen import G, zeichne
from schleifen_bedingungen import verbindungen, nachbarpunkte, kosten, einmal_wuerfeln, erstelle_tabelle_ohne_duplikate

zeichne(G)

# %% [markdown]
# Jede Verbindung zwischen zwei Wegabschnitten ist in folgender Tabelle gespeichert.

# %%
verbindungen
# Out:
#        von     bis  Lebenspunkte
# 0    Start       c        12.345
# 1        c   Zwerg        34.395
# 2        c   Riese        33.726
# 3        c  Magier        10.592
# 4   Magier    Hexe        20.459
# 5        c    Hexe         9.112
# 6     Hexe       y        39.906
# 7   Magier       y        58.251
# 8        c       y        41.842
# 9    Zwerg       y        22.144
# 10   Riese       y         6.901
# 11       y  Schatz        10.390
# 0        c   Start        12.345
# 1    Zwerg       c        34.395
# 2    Riese       c        33.726
# 3   Magier       c        10.592
# 4     Hexe  Magier        20.459
# 5     Hexe       c         9.112
# 6        y    Hexe        39.906
# 7        y  Magier        58.251
# 8        y       c        41.842
# 9        y   Zwerg        22.144
# 10       y   Riese         6.901
# 11  Schatz       y        10.390

# %% [markdown]
# Zusätzlich dazu, wurden oben Funktionen importiert mit denen man sehr einfach
# - Nachbarpunkt zu bestimmten Punkten
# - die Kosten von Punkt A zu Punkt B
#
# berechnen kann. Diese findest du hier.

# %%
# Die Reihenfolge der ausgegebenen Nachbarpunkte ist jedes Mal anders. Das ist wichtig, damit wir im Folgenden
# einfachen Zugang zu unterschiedlichen Nachbarn bekommen
nachbarpunkte("y")
# Out:
# ['c', 'Magier', 'Zwerg', 'Riese', 'Schatz', 'Hexe']

# %%
kosten("c", "Zwerg")
# Out:
# 34.394999999999996

# %% [markdown]
# ### Aufgabe 4
#
# Wir wollen nun das erlernte Wissen nutzen, um einen Algorithmus zu schreiben, der automatisch einen (zufälligen) Weg vom Start zum Schatz erstellt und dabei die Wegkosten aufsummiert.
# Es gibt dabei folgende Variablen:

# %%
mein_ort = "Start"
mein_ziel = "Schatz"

# Folgende Liste speichert alle Punkte, die schon passiert worden sind
mein_weg = [mein_ort]

# Diese Zahl entspricht den Gesamtkosten an Lebenspunkten auf unserem bisherigen Weg
meine_kosten = 0

# %% [markdown]
# Der Algorithmus soll folgende Dinge tun:
#
# - Laufe solange (**while**) weiter bis dein Ort dem Ziel entspricht.
# - An jedem Wegpunkt wird zu einem der Nachbarpunkte (**for**) gegangen werden
# - Wenn der Nachbarpunkt schon auf dem bisherigen Weg liegt, soll er, wenn möglich gemieden werden (**if**), wenn es nicht anders möglich ist, darf er aber auch ausnahmsweise betreten werden
#
# Hier noch ein Paar Hinweise:

# %%
# Hinweis 1: Um zu testen, ob zwei Zeichenketten ungleich sind, können wir folgendes tun
z1 = "abc"
z2 = "xyz"
z1 != z2
# Out:
# True

# %%
# Hinweis 2: Um zu testen, ob ein Element nicht in einer List ist, können wir folgendes tun
meine_liste = [1, 3, 5]
meine_zahl = 2

meine_zahl not in meine_liste
# Out:
# True

# %%
# Hinweis 3: Um Schleifen vorzeitig zu verlassen, können wir **break** nutzen
meine_liste = [1, 3, 5]
meine_zahl = 2

for element in meine_liste:
    print(element)
    if element > meine_zahl:
        break

print("Erstes größeres Element:", element)
# Out:
# 1
# 3
# Erstes größeres Element: 3

# %%
mein_ort = "Start"
mein_ziel = "Schatz"
mein_weg = [mein_ort]
meine_kosten = 0

# Bedingung: Ort ist ungleich Ziel (Hinweis 1) ...
while mein_ort != mein_ziel:
   
    nachbarn = nachbarpunkte(mein_ort)

    n = nachbarn[0]

    meine_kosten = meine_kosten + kosten(n, mein_ort)
    mein_ort = n
    mein_weg.append(mein_ort)
   
print("Du bist am Ziel!")
print("Der Weg:", mein_weg)
print("Gesamtkosten", meine_kosten)
# Out:
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'Magier', 'y', 'Magier', 'Hexe', 'Magier', 'c', 'Zwerg', 'y', 'Zwerg', 'c', 'Start', 'c', 'Riese', 'y', 'Magier', 'y', 'Schatz']
# Gesamtkosten 537.154

# %% [markdown]
# ### Aufgabe 5
#
# Wir wollen ja nun, den besten Weg automatisch finden. Dazu schreiben wir obigen Code in eine Funktion:

# %%
def probiere_weg_aus():

    mein_ort = "Start"
    mein_ziel = "Schatz"
    mein_weg = [mein_ort]
    meine_kosten = 0

    # Bedingung: Ort ist ungleich Ziel (Hinweis 1) ...
    while mein_ort != mein_ziel:
    
        nachbarn = nachbarpunkte(mein_ort)

        n = nachbarn[0]

        meine_kosten = meine_kosten + kosten(n, mein_ort)
        mein_ort = n
        mein_weg.append(mein_ort)
    
    print("Du bist am Ziel!")
    print("Der Weg:", mein_weg)
    print("Gesamtkosten", meine_kosten)

               # Dein Code hier

    return mein_weg, meine_kosten

# %% [markdown]
# Die Funktion probieren nun sehr oft aus und speichern das Ergebnis in einer Tabelle.

# %%
anzahl_versuche = 50
versuch_nummer = 1
ergebnisse = []
while versuch_nummer != anzahl_versuche:
    ergebnis = probiere_weg_aus()
    ergebnisse.append(ergebnis)
    versuch_nummer = versuch_nummer + 1

ergebnis_tabelle = erstelle_tabelle_ohne_duplikate(ergebnisse)
# Out:
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'Magier', 'y', 'Zwerg', 'c', 'y', 'Schatz']
# Gesamtkosten 208.938
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Riese', 'c', 'Zwerg', 'c', 'Start', 'c', 'Hexe', 'Magier', 'y', 'Magier', 'c', 'Magier', 'y', 'Magier', 'y', 'Magier', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 683.0969999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'c', 'Riese', 'y', 'Riese', 'y', 'c', 'Riese', 'c', 'Start', 'c', 'Start', 'c', 'Start', 'c', 'y', 'Hexe', 'Magier', 'Hexe', 'y', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'Magier', 'c', 'Riese', 'y', 'Magier', 'Hexe', 'c', 'Magier', 'Hexe', 'Magier', 'Hexe', 'Magier', 'c', 'y', 'Hexe', 'y', 'Magier', 'Hexe', 'Magier', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 1128.7130000000004
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'y', 'Riese', 'c', 'Riese', 'c', 'Hexe', 'y', 'Zwerg', 'c', 'Start', 'c', 'Start', 'c', 'y', 'Riese', 'c', 'Zwerg', 'y', 'Riese', 'c', 'y', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'Magier', 'y', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 892.8280000000001
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'y', 'Schatz']
# Gesamtkosten 91.578
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Riese', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 92.18099999999998
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'c', 'Zwerg', 'c', 'Start', 'c', 'Hexe', 'y', 'Zwerg', 'c', 'Riese', 'y', 'Hexe', 'c', 'Zwerg', 'y', 'c', 'Zwerg', 'y', 'Hexe', 'y', 'Riese', 'y', 'Zwerg', 'y', 'Hexe', 'c', 'Magier', 'y', 'Riese', 'c', 'Riese', 'c', 'Start', 'c', 'Magier', 'y', 'Hexe', 'Magier', 'c', 'Hexe', 'c', 'Hexe', 'y', 'Riese', 'c', 'Hexe', 'y', 'Riese', 'y', 'Zwerg', 'c', 'Magier', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 1361.6440000000005
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'Zwerg', 'y', 'Hexe', 'c', 'Riese', 'c', 'Hexe', 'c', 'Zwerg', 'y', 'Zwerg', 'c', 'Magier', 'y', 'Magier', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 577.9989999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Riese', 'c', 'Hexe', 'y', 'Zwerg', 'c', 'Hexe', 'c', 'Hexe', 'y', 'Zwerg', 'y', 'c', 'Hexe', 'c', 'Start', 'c', 'Riese', 'y', 'Riese', 'c', 'Zwerg', 'c', 'Zwerg', 'y', 'Zwerg', 'c', 'Start', 'c', 'y', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'Start', 'c', 'Start', 'c', 'y', 'Schatz']
# Gesamtkosten 941.6460000000001
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'c', 'y', 'c', 'Hexe', 'y', 'c', 'Riese', 'y', 'Zwerg', 'c', 'y', 'Riese', 'c', 'Riese', 'y', 'Schatz']
# Gesamtkosten 435.765
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Riese', 'y', 'Hexe', 'c', 'Riese', 'y', 'Schatz']
# Gesamtkosten 168.024
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'c', 'Magier', 'c', 'Zwerg', 'c', 'y', 'Hexe', 'Magier', 'y', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 431.946
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'c', 'y', 'Hexe', 'c', 'Zwerg', 'c', 'Zwerg', 'y', 'Schatz']
# Gesamtkosten 307.71399999999994
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'c', 'Riese', 'c', 'y', 'Hexe', 'Magier', 'y', 'Magier', 'y', 'Riese', 'y', 'Hexe', 'y', 'Hexe', 'c', 'Riese', 'c', 'Start', 'c', 'Magier', 'Hexe', 'c', 'Hexe', 'Magier', 'c', 'Zwerg', 'c', 'Zwerg', 'c', 'Magier', 'c', 'Riese', 'c', 'Magier', 'Hexe', 'Magier', 'c', 'Riese', 'y', 'Magier', 'y', 'Magier', 'Hexe', 'c', 'Hexe', 'c', 'Hexe', 'Magier', 'Hexe', 'c', 'Hexe', 'Magier', 'y', 'Riese', 'c', 'Zwerg', 'y', 'Riese', 'c', 'Magier', 'Hexe', 'y', 'Riese', 'c', 'Start', 'c', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'Magier', 'y', 'Zwerg', 'c', 'Magier', 'c', 'Riese', 'c', 'Zwerg', 'c', 'Zwerg', 'y', 'Riese', 'y', 'c', 'Start', 'c', 'Magier', 'c', 'Zwerg', 'c', 'Magier', 'y', 'c', 'Riese', 'c', 'Zwerg', 'y', 'Riese', 'y', 'Magier', 'Hexe', 'y', 'Hexe', 'Magier', 'y', 'Zwerg', 'c', 'Riese', 'c', 'Zwerg', 'c', 'Riese', 'y', 'Magier', 'c', 'Hexe', 'y', 'c', 'Hexe', 'c', 'Zwerg', 'y', 'Hexe', 'c', 'Riese', 'c', 'Hexe', 'y', 'Riese', 'c', 'Start', 'c', 'y', 'Zwerg', 'c', 'Riese', 'c', 'Magier', 'y', 'Hexe', 'Magier', 'Hexe', 'c', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 3930.0990000000015
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Hexe', 'Magier', 'Hexe', 'y', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 303.923
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'c', 'Zwerg', 'c', 'Zwerg', 'c', 'Magier', 'c', 'Hexe', 'y', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 417.9229999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'Riese', 'c', 'y', 'c', 'Start', 'c', 'y', 'Hexe', 'c', 'Hexe', 'c', 'Zwerg', 'c', 'Zwerg', 'y', 'Zwerg', 'y', 'Hexe', 'Magier', 'c', 'Start', 'c', 'y', 'Hexe', 'y', 'c', 'Zwerg', 'c', 'Start', 'c', 'Start', 'c', 'y', 'Riese', 'c', 'Hexe', 'y', 'Magier', 'y', 'Zwerg', 'y', 'Riese', 'y', 'Riese', 'c', 'Riese', 'y', 'c', 'Start', 'c', 'Hexe', 'Magier', 'c', 'Hexe', 'Magier', 'c', 'Start', 'c', 'Riese', 'c', 'Start', 'c', 'Zwerg', 'c', 'Magier', 'y', 'Zwerg', 'y', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 1792.021000000001
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'y', 'Riese', 'c', 'Riese', 'c', 'Hexe', 'y', 'Hexe', 'Magier', 'c', 'Start', 'c', 'Hexe', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 394.83799999999997
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'y', 'Hexe', 'y', 'Riese', 'y', 'Riese', 'c', 'Zwerg', 'y', 'Zwerg', 'y', 'Hexe', 'y', 'Magier', 'y', 'Schatz']
# Gesamtkosten 525.0740000000001
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'Magier', 'Hexe', 'c', 'Start', 'c', 'Magier', 'y', 'Riese', 'c', 'Magier', 'c', 'y', 'Riese', 'c', 'Start', 'c', 'Magier', 'y', 'Hexe', 'Magier', 'Hexe', 'c', 'Magier', 'c', 'Magier', 'Hexe', 'y', 'Hexe', 'Magier', 'Hexe', 'c', 'Riese', 'y', 'Zwerg', 'c', 'Hexe', 'Magier', 'c', 'Start', 'c', 'Zwerg', 'c', 'Riese', 'y', 'Hexe', 'Magier', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 1077.4019999999998
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'y', 'Hexe', 'y', 'c', 'Zwerg', 'c', 'Magier', 'c', 'Hexe', 'c', 'Start', 'c', 'Start', 'c', 'Magier', 'y', 'Hexe', 'y', 'Hexe', 'Magier', 'c', 'Magier', 'y', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'Zwerg', 'c', 'y', 'Magier', 'y', 'Hexe', 'Magier', 'Hexe', 'c', 'Start', 'c', 'Zwerg', 'c', 'Riese', 'c', 'Magier', 'y', 'Schatz']
# Gesamtkosten 1315.0250000000005
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'c', 'y', 'c', 'y', 'Hexe', 'c', 'y', 'Schatz']
# Gesamtkosten 260.305
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Riese', 'y', 'Riese', 'y', 'Riese', 'c', 'y', 'Hexe', 'y', 'Riese', 'y', 'c', 'y', 'Hexe', 'Magier', 'Hexe', 'Magier', 'y', 'Riese', 'c', 'Zwerg', 'c', 'Hexe', 'y', 'Hexe', 'y', 'Zwerg', 'c', 'Start', 'c', 'Zwerg', 'y', 'c', 'Zwerg', 'c', 'Start', 'c', 'y', 'c', 'Start', 'c', 'Zwerg', 'y', 'c', 'Hexe', 'Magier', 'y', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 1382.1910000000003
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Riese', 'y', 'Hexe', 'Magier', 'c', 'y', 'Zwerg', 'c', 'Start', 'c', 'Magier', 'Hexe', 'Magier', 'y', 'Magier', 'c', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 538.8329999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'c', 'Riese', 'c', 'Zwerg', 'y', 'c', 'Hexe', 'Magier', 'c', 'Start', 'c', 'y', 'Magier', 'y', 'Hexe', 'y', 'Hexe', 'y', 'Riese', 'y', 'Hexe', 'Magier', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 738.7929999999996
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'c', 'Zwerg', 'c', 'y', 'c', 'Magier', 'c', 'Zwerg', 'y', 'Zwerg', 'y', 'Magier', 'Hexe', 'y', 'Riese', 'y', 'Magier', 'c', 'Start', 'c', 'Magier', 'c', 'y', 'Schatz']
# Gesamtkosten 607.381
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'Magier', 'c', 'Zwerg', 'c', 'Riese', 'c', 'Riese', 'c', 'Hexe', 'Magier', 'y', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 456.16499999999996
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'Start', 'c', 'Start', 'c', 'Hexe', 'y', 'Riese', 'y', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 239.437
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'c', 'Riese', 'c', 'Zwerg', 'y', 'Zwerg', 'c', 'y', 'Zwerg', 'c', 'Riese', 'c', 'Hexe', 'c', 'Riese', 'c', 'Riese', 'c', 'y', 'Schatz']
# Gesamtkosten 582.2919999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Schatz']
# Gesamtkosten 64.577
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'c', 'y', 'c', 'Riese', 'y', 'Schatz']
# Gesamtkosten 230.72999999999996
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'Magier', 'c', 'Zwerg', 'y', 'Riese', 'c', 'Hexe', 'y', 'Schatz']
# Gesamtkosten 209.082
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'Riese', 'y', 'Magier', 'c', 'Hexe', 'c', 'Hexe', 'Magier', 'c', 'Magier', 'Hexe', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 300.041
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'c', 'Zwerg', 'c', 'Magier', 'Hexe', 'y', 'Magier', 'c', 'Zwerg', 'y', 'Magier', 'Hexe', 'Magier', 'c', 'Magier', 'c', 'Hexe', 'y', 'c', 'Zwerg', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 648.7999999999998
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'y', 'c', 'Hexe', 'Magier', 'c', 'Start', 'c', 'Riese', 'y', 'Riese', 'c', 'Magier', 'y', 'Schatz']
# Gesamtkosten 348.37
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Start', 'c', 'Hexe', 'Magier', 'Hexe', 'c', 'Zwerg', 'y', 'Magier', 'c', 'Riese', 'c', 'Zwerg', 'c', 'y', 'Hexe', 'c', 'y', 'c', 'Magier', 'Hexe', 'Magier', 'c', 'Hexe', 'c', 'Zwerg', 'y', 'Magier', 'c', 'Magier', 'Hexe', 'y', 'Riese', 'y', 'Schatz']
# Gesamtkosten 833.2019999999997
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'y', 'Schatz']
# Gesamtkosten 79.27399999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'y', 'c', 'Hexe', 'Magier', 'c', 'Riese', 'c', 'Hexe', 'c', 'Zwerg', 'y', 'Riese', 'c', 'Hexe', 'Magier', 'y', 'Zwerg', 'c', 'Start', 'c', 'Magier', 'c', 'Hexe', 'y', 'Riese', 'c', 'Riese', 'c', 'Magier', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'Start', 'c', 'Riese', 'y', 'Hexe', 'c', 'Magier', 'Hexe', 'y', 'Zwerg', 'y', 'Magier', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 1214.8700000000001
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'c', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'y', 'Schatz']
# Gesamtkosten 185.82099999999997
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'c', 'Riese', 'c', 'Zwerg', 'y', 'Hexe', 'y', 'c', 'Riese', 'c', 'Hexe', 'c', 'Hexe', 'Magier', 'y', 'c', 'y', 'Zwerg', 'c', 'Magier', 'c', 'Riese', 'y', 'Schatz']
# Gesamtkosten 665.0959999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'y', 'c', 'Hexe', 'y', 'Hexe', 'Magier', 'y', 'Schatz']
# Gesamtkosten 281.229
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'Magier', 'Hexe', 'Magier', 'c', 'y', 'Riese', 'y', 'Zwerg', 'y', 'Magier', 'c', 'Riese', 'c', 'Start', 'c', 'Start', 'c', 'Magier', 'y', 'Riese', 'y', 'Magier', 'c', 'Riese', 'y', 'Magier', 'y', 'Hexe', 'y', 'Hexe', 'y', 'Magier', 'y', 'Schatz']
# Gesamtkosten 974.1659999999997
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'Magier', 'c', 'Riese', 'c', 'Riese', 'y', 'Riese', 'c', 'Zwerg', 'y', 'Zwerg', 'c', 'Zwerg', 'y', 'Hexe', 'c', 'Hexe', 'Magier', 'Hexe', 'Magier', 'Hexe', 'c', 'Riese', 'y', 'c', 'Hexe', 'c', 'Magier', 'y', 'c', 'Start', 'c', 'Start', 'c', 'Magier', 'Hexe', 'c', 'Magier', 'c', 'Riese', 'y', 'Zwerg', 'c', 'Zwerg', 'c', 'Start', 'c', 'y', 'Hexe', 'y', 'Zwerg', 'y', 'c', 'y', 'Schatz']
# Gesamtkosten 1292.6760000000002
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Schatz']
# Gesamtkosten 64.577
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'c', 'Magier', 'y', 'Riese', 'c', 'Start', 'c', 'Magier', 'Hexe', 'y', 'c', 'Hexe', 'y', 'Zwerg', 'c', 'Magier', 'y', 'Zwerg', 'y', 'Magier', 'y', 'Schatz']
# Gesamtkosten 645.0469999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Magier', 'Hexe', 'c', 'Riese', 'c', 'y', 'Riese', 'c', 'y', 'c', 'y', 'Zwerg', 'y', 'Zwerg', 'y', 'Magier', 'y', 'Riese', 'c', 'Magier', 'Hexe', 'c', 'y', 'Zwerg', 'y', 'Riese', 'y', 'Zwerg', 'c', 'Zwerg', 'y', 'Zwerg', 'y', 'Schatz']
# Gesamtkosten 881.5109999999999
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'y', 'Hexe', 'c', 'Magier', 'Hexe', 'c', 'Zwerg', 'y', 'Riese', 'y', 'Zwerg', 'c', 'Magier', 'Hexe', 'y', 'c', 'Start', 'c', 'Zwerg', 'c', 'Hexe', 'y', 'c', 'Hexe', 'c', 'Zwerg', 'y', 'Hexe', 'c', 'Riese', 'c', 'Hexe', 'c', 'Hexe', 'c', 'Riese', 'c', 'Start', 'c', 'Magier', 'Hexe', 'y', 'Zwerg', 'c', 'Zwerg', 'y', 'Schatz']
# Gesamtkosten 1081.6349999999998
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Hexe', 'c', 'Start', 'c', 'Start', 'c', 'Riese', 'c', 'Riese', 'y', 'Zwerg', 'y', 'Schatz']
# Gesamtkosten 242.70600000000002
# Du bist am Ziel!
# Der Weg: ['Start', 'c', 'Zwerg', 'y', 'c', 'Hexe', 'c', 'Start', 'c', 'Hexe', 'c', 'Magier', 'Hexe', 'c', 'Magier', 'y', 'c', 'Magier', 'c', 'Riese', 'y', 'Magier', 'c', 'Start', 'c', 'Riese', 'c', 'Start', 'c', 'Zwerg', 'y', 'Hexe', 'y', 'Zwerg', 'y', 'Magier', 'Hexe', 'y', 'Zwerg', 'c', 'Magier', 'Hexe', 'c', 'Magier', 'y', 'Schatz']
# Gesamtkosten 1045.388

# %% [markdown]
# Hier siehst du die Ergebnisse als Tabelle!

# %%
ergebnis_tabelle
# Out:
#                                                   Weg  Gesamtkosten
# 29                              [Start, c, y, Schatz]        64.577
# 36                       [Start, c, Zwerg, y, Schatz]        79.274
# 4                       [Start, c, Magier, y, Schatz]        91.578
# 5           [Start, c, y, Riese, y, Riese, y, Schatz]        92.181
# 10  [Start, c, y, Riese, y, Hexe, c, Riese, y, Sch...       168.024
# 38  [Start, c, Magier, c, Hexe, Magier, Hexe, Magi...       185.821
# 0    [Start, c, Hexe, Magier, y, Zwerg, c, y, Schatz]       208.938
# 31  [Start, c, Hexe, Magier, c, Zwerg, y, Riese, c...       209.082
# 30           [Start, c, y, c, y, c, Riese, y, Schatz]       230.730
# 27  [Start, c, Start, c, Start, c, Start, c, Hexe,...       239.437
# 47  [Start, c, Hexe, c, Start, c, Start, c, Riese,...       242.706
# 21  [Start, c, Magier, c, y, c, y, Hexe, c, y, Sch...       260.305
# 40  [Start, c, Hexe, y, c, Hexe, y, Hexe, Magier, ...       281.229
# 32  [Start, c, Start, c, Riese, y, Magier, c, Hexe...       300.041
# 14  [Start, c, y, Hexe, Magier, Hexe, y, Hexe, Mag...       303.923
# 12  [Start, c, Zwerg, c, y, Hexe, c, Zwerg, c, Zwe...       307.714
# 34  [Start, c, Magier, y, c, Hexe, Magier, c, Star...       348.370
# 17  [Start, c, Zwerg, y, Riese, c, Riese, c, Hexe,...       394.838
# 15  [Start, c, Zwerg, c, Zwerg, c, Zwerg, c, Magie...       417.923
# 11  [Start, c, Magier, Hexe, c, Magier, c, Zwerg, ...       431.946
# 9   [Start, c, Hexe, c, y, c, Hexe, y, c, Riese, y...       435.765
# 26  [Start, c, Magier, Hexe, Magier, c, Zwerg, c, ...       456.165
# 18  [Start, c, Magier, Hexe, y, Hexe, y, Riese, y,...       525.074
# 23  [Start, c, y, Riese, y, Hexe, Magier, c, y, Zw...       538.833
# 7   [Start, c, Start, c, Zwerg, y, Hexe, c, Riese,...       577.999
# 28  [Start, c, Hexe, c, Riese, c, Zwerg, y, Zwerg,...       582.292
# 25  [Start, c, Magier, c, Zwerg, c, y, c, Magier, ...       607.381
# 44  [Start, c, Magier, Hexe, c, Magier, y, Riese, ...       645.047
# 33  [Start, c, Zwerg, c, Zwerg, c, Magier, Hexe, y...       648.800
# 39  [Start, c, Magier, c, Riese, c, Zwerg, y, Hexe...       665.096
# 1   [Start, c, Riese, c, Zwerg, c, Start, c, Hexe,...       683.097
# 24  [Start, c, Magier, c, Riese, c, Zwerg, y, c, H...       738.793
# 35  [Start, c, Start, c, Hexe, Magier, Hexe, c, Zw...       833.202
# 45  [Start, c, Magier, Hexe, c, Riese, c, y, Riese...       881.511
# 3   [Start, c, Start, c, y, Riese, c, Riese, c, He...       892.828
# 8   [Start, c, Riese, c, Hexe, y, Zwerg, c, Hexe, ...       941.646
# 41  [Start, c, Hexe, Magier, Hexe, Magier, c, y, R...       974.166
# 48  [Start, c, Zwerg, y, c, Hexe, c, Start, c, Hex...      1045.388
# 19  [Start, c, Hexe, Magier, Hexe, c, Start, c, Ma...      1077.402
# 46  [Start, c, y, Hexe, c, Magier, Hexe, c, Zwerg,...      1081.635
# 2   [Start, c, Magier, Hexe, c, Riese, y, Riese, y...      1128.713
# 37  [Start, c, Magier, Hexe, y, c, Hexe, Magier, c...      1214.870
# 42  [Start, c, Hexe, Magier, c, Riese, c, Riese, y...      1292.676
# 20  [Start, c, Hexe, y, Hexe, y, c, Zwerg, c, Magi...      1315.025
# 6   [Start, c, Zwerg, c, Zwerg, c, Start, c, Hexe,...      1361.644
# 22  [Start, c, Riese, y, Riese, y, Riese, c, y, He...      1382.191
# 16  [Start, c, Start, c, Riese, c, y, c, Start, c,...      1792.021
# 13  [Start, c, Zwerg, c, Riese, c, y, Hexe, Magier...      3930.099
